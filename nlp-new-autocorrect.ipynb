# %%
import os
import re
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Bidirectional, Dense, TimeDistributed
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dropout, LayerNormalization


# Normalisation for Arabic text
def normalize_arabic(text):
    text = re.sub(r'[ًٌٍَُِّْـ]', '', text)
    text = re.sub(r'[إأآا]', 'ا', text)
    text = re.sub(r'ى', 'ي', text)
    text = re.sub(r'ؤ', 'و', text)
    text = re.sub(r'ئ', 'ي', text)
    text = re.sub(r'ة', 'ه', text)
    return text

# Sentence splitter
def split_into_sentences(text):
    return [sentence.strip() for sentence in re.split(r'[.!؟\n]', text) if sentence.strip()]

# %%
# Arabic keyboard proximity map
arabic_keyboard = {
    'ا': ['أ', 'إ', 'ء', 'ى'],
    'ب': ['ن', 'ت'],
    'ت': ['ب', 'ن'],
    'ث': ['ت', 'س'],
    'ج': ['ح', 'خ'],
    'ح': ['ج', 'خ'],
    'خ': ['ح', 'ج'],
    'د': ['ذ'],
    'ذ': ['د', 'ر'],
    'ر': ['ذ', 'ز'],
    'ز': ['ر', 'س'],
    'س': ['ش', 'ص'],
    'ش': ['س', 'ص'],
    'ص': ['س', 'ش', 'ض'],
    'ض': ['ص', 'ط'],
    'ط': ['ض', 'ظ'],
    'ع': ['غ'],
    'غ': ['ع'],
    'ف': ['ق'],
    'ق': ['ف'],
    'ك': ['ل'],
    'ل': ['ك'],
    'م': ['ن'],
    'ن': ['م', 'ب'],
    'ه': ['ة'],
    'ة': ['ه'],
    'ي': ['ى', 'ب'],
    'ى': ['ي']
}

def keyboard_substitute(char):
    if char in arabic_keyboard:
        return random.choice(arabic_keyboard[char])
    return char

def insert_typo(word):
    if len(word) < 2:
        return word
    # typo_type = random.choice(['delete', 'insert', 'substitute'])
    typo_type = 'substitute'
    i = random.randint(0, len(word) - 1)
    arabic_chars = 'ابتثجحخدذرزسشصضطظعغفقكلمنهوي'

    if typo_type == 'delete':
        return word[:i] + word[i+1:]
    elif typo_type == 'insert':
        return word[:i] + random.choice(arabic_chars) + word[i:]
    elif typo_type == 'substitute':
        return word[:i] + keyboard_substitute(word[i]) + word[i+1:]
    return word

def corrupt_sentence(sentence, error_probability=0.1):
    words = sentence.split()
    corrupted = [insert_typo(w) if random.random() < error_probability else w for w in words]
    return ' '.join(corrupted)

# %%
# Load your .tsv dataset 
df = pd.read_csv('unbalanced_reviews.tsv', sep='\t', header=None)

# Column 4 contains the Arabic review text
texts = df[4].astype(str).tolist()

# Normalize and split into sentences
all_sentences = []
for text in texts:
    norm_text = normalize_arabic(text)
    all_sentences.extend(split_into_sentences(norm_text))

# Filter sentences by length
clean_sentences = [s for s in all_sentences if 5 < len(s) < 100]
clean_sentences = list(set(clean_sentences))  # Remove duplicates
noisy_sentences = [corrupt_sentence(s) for s in clean_sentences]

print(f"Clean samples: {len(clean_sentences)}")
# Out:
# Clean samples: 2182769

# %%
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(clean_sentences + noisy_sentences)

vocab_size = len(tokenizer.word_index) + 1
max_len = max(len(s) for s in clean_sentences)

def encode(sentences):
    sequences = tokenizer.texts_to_sequences(sentences)
    return pad_sequences(sequences, maxlen=max_len, padding='post')

X = encode(noisy_sentences)
Y = encode(clean_sentences)
Y = Y[..., None]  # Make shape (batch_size, sequence_length, 1)

# %%
embedding_dim = 300
lstm_units = 256
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_len, input_shape=(max_len,)),
    Bidirectional(LSTM(lstm_units, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(128, return_sequences=True)),
    TimeDistributed(Dense(vocab_size, activation='softmax'))
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ (None, 99, 300)             │          50,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_4 (Bidirectional)      │ (None, 99, 512)             │       1,140,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 99, 512)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_5 (Bidirectional)      │ (None, 99, 256)             │         656,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_2 (TimeDistributed) │ (None, 99, 168)             │          43,176 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,890,696 (7.21 MB)
#  Trainable params: 1,890,696 (7.21 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import load_model

# reducing learning rate when improvement decreases
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6
)

# stops if validation accuracy doesn't increase for 5 consecutive epochs 
early_stop = EarlyStopping(
    patience=5,
    restore_best_weights=True,
    monitor='val_accuracy',
    mode='max'
)

# saves the best model, even if it isn't the last one
checkpoint = ModelCheckpoint(
    filepath='/kaggle/working/best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# trains the model. epochs can be changed accordingly 
model.fit(
    X_train, Y_train,
    epochs=1,
    batch_size=64,
    validation_data=(X_test, Y_test),
    callbacks=[checkpoint, early_stop, reduce_lr]
)
# Out:
# 27285/27285 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9887 - loss: 0.0510
# Epoch 1: val_accuracy improved from -inf to 0.99765, saving model to /kaggle/working/best_model.keras
# 27285/27285 ━━━━━━━━━━━━━━━━━━━━ 1765s 64ms/step - accuracy: 0.9887 - loss: 0.0510 - val_accuracy: 0.9976 - val_loss: 0.0102 - learning_rate: 0.0010

# %%
model = load_model('best_model.keras')

def decode_sequence(pred):
    pred_ids = np.argmax(pred, axis=-1)
    index_word = {v: k for k, v in tokenizer.word_index.items()}
    return ''.join([index_word.get(i, '') for i in pred_ids])

def autocorrect(input_text):
    input_text = normalize_arabic(input_text)
    seq = encode([input_text])
    pred = model.predict(seq)
    return decode_sequence(pred[0])

# %%
# Example test
sentences_with_typos = [
    "أنا أجب المدرسة",     # أحب → أجب
    "هو يقأ كتابًا",       # يقرأ → يقأ
    "الحو جميل اليوم",     # الجو → الحو
    "ذهبت إلى السىق",      # السوق → السىق
    "هي تطبخ الطعان",      # الطعام → الطعان
    "القط يحلس هناك",      # يجلس → يحلس
    "الولد يكتب الواخب",   # الواجب → الواخب
    "أين حخيبتي؟",         # حقيبتي → حخيبتي
    "أنا متعب قببلاً",     # قليلاً → قببلاً
    "نحن نلعب في الجديقة", # الحديقة → الجديقة
    "السماء زرقاء صافبة",  # صافية → صافبة
    "هل أكلت القبور؟",     # الفطور → القبور
    "أريد شرب الهاء",      # الماء → الهاء
    "السيارة سريعة جذاً",  # جداً → جذاً
    "الوقت متأحر الآن",    # متأخر → متأحر
    "أحب كرة القدن",       # القدم → القدن
    "هو يعمل بحد",         # بجد → بحد
    "الطفل نائك",          # نائم → نائك
    "أين المغاتيح؟",       # المفاتيح → المغاتيح
    "الشارع مزذحم"         # مزدحم → مزذحم
]
for test_input in sentences_with_typos:
    print("Noisy input:    ", test_input)
    print("Autocorrected:  ", autocorrect(test_input))
# Out:
# Noisy input:     أنا أجب المدرسة
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Autocorrected:   انا احب المدرسه
# Noisy input:     هو يقأ كتابًا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   هو يقا كتابا
# Noisy input:     الحو جميل اليوم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   الحو جميل اليوم
# Noisy input:     ذهبت إلى السىق
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   ذهبت الي السيق
# Noisy input:     هي تطبخ الطعان
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Autocorrected:   هي تطبخ الطعان
# Noisy input:     القط يحلس هناك
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Autocorrected:   القط يحلس هناك
# Noisy input:     الولد يكتب الواخب
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Autocorrected:   الولد يكتب الواخب
# Noisy input:     أين حخيبتي؟
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Autocorrected:   اين حخيبتي
# Noisy input:     أنا متعب قببلاً
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Autocorrected:   انا متعب قببلا
# Noisy input:     نحن نلعب في الجديقة
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   نحن نلعب في الجديقه
# Noisy input:     السماء زرقاء صافبة
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   السماء زرقاء صافيه
# Noisy input:     هل أكلت القبور؟
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   هل اكلت القبور
# Noisy input:     أريد شرب الهاء
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Autocorrected:   اريد شرب الهاء
# Noisy input:     السيارة سريعة جذاً
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Autocorrected:   السياره سريعه جدا
# Noisy input:     الوقت متأحر الآن
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Autocorrected:   الوقت متاحر الان
# Noisy input:     أحب كرة القدن
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   احب كره القدم
# Noisy input:     هو يعمل بحد
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Autocorrected:   هو يعمل بحد
# Noisy input:     الطفل نائك
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Autocorrected:   الطفل نايك
# Noisy input:     أين المغاتيح؟
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   اين المغاتيح
# Noisy input:     الشارع مزذحم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Autocorrected:   الشارع مزرحم

# %%
from difflib import SequenceMatcher

def sentence_similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()

scores = [sentence_similarity(clean, autocorrect(noisy)) for clean, noisy in zip(clean_sentences[:100], noisy_sentences[:100])]
print(f"Avg sentence similarity: {np.mean(scores):.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Avg sentence similarity: 0.9819

# %%
def evaluate_sentence_level_accuracy(clean_list, noisy_list):
    correct_count = 0
    total = len(clean_list)
    for clean, noisy in zip(clean_list, noisy_list):
        prediction = autocorrect(noisy)
        if prediction == clean:
            correct_count +=1
        print(clean)
        print(noisy)
    print(f"Sentence-level accuracy: {correct_count / total:.4f}")

evaluate_sentence_level_accuracy(clean_sentences[500:700], noisy_sentences[500:700])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# معامله الاخر لك التحيزات الخفيه ووسايل اخفاء الضعف التي نتقنها
# معامله الاخر لك التحيزات الخفيه ووسايل اخفاء الضعف التي نتقنها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# - التقافز ما بين اوتار الزمن مربك، رغم انه بدا مبرر قرب النهايه
# - التقافز ما تين اوتار الزمن مربك، رغم انة بدا مبرر قرب النهايه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# كتيب لطيف لم تسلبني ادبيته كما عاده احلام
# كتيت لطيف لم تسلبني ادبيته كما عاده احلام
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# مش قوي بالمره
# مش قوي بالمره
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# فالكتاب عملي جدا و ذو اسلوب مباشر
# فالكتاب عملي جدا و ذو اسلوب مباشر
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# توكل سينا ابراهيم
# تولل سىنا ابراهيم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ?- كثره الايحاءات الجنسيه في الكتاب، ووجود صور لنساء
# ?- كثره الايحاءات الجبسيه في الكتاب، ووجود صور لنساء
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# - الغياب شكل من اشكال الحضور، يغيب البعض وهم حاضرون في اذهاننا اكثر من وقت حضورهم في حياتنا
# - الغياب شكل من اشكال الحضور، يغيب البعض وهم حاضرون في اذهاننا اكثر من وقت حضورةم في حياتنا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# كل ماستحتاج اليه لذلك
# كك ماستحتاج اليه لذلك
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# نردين ابو نبعه لامست قلبي و عقلي في روايتها
# نردين ابو نبعه لامست قلبي و عقلي في روايتها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لقصه لويس كارول الاصليه يخفف جرعه الغرابه، فعلي سبيل المثال، انا مولعه بفلم
# لقصه كويس كارول الاصليه يخفف جرعه الغرابه، فعلي سبيل المثال، انا مولعه بفلم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# الصدام
# الصدام
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# اني وكيدعم ما عبثوا به كالطود يحقر بطحه الاوعال
# اني وكيدعم مء عبثوا به كالطود يحقر بطحه الاوعال
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# السرد واللغه
# السرد واللغه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ولكن علاقه ود وموده ورحمه ، يزيدها الزمن متانه وقوه وحكمه
# وللن علاقه ود وموده ورحمه ، يزىدها الزمن متانه وقوه وحكمه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# مختلف بقاع الارض ضد الديكتاتوريات سواء كانوا عسكريين او قساوسه وحتي الكنيسه نفسها فضح نفاق رجالها
# مختلف بقاع الارض ضد الديكتاتوريات سواء كانوا عسكريين او قساوسه وحتي الكنيسه نفسها فضج نفاق رجالها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# قرات قصص قصيره من قبل ولكن المخزنجي هنا بالفعل مختلف
# قرات قصص قصيره من قبل ولكن المخزنجي هنا بالفعل مختلف
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# كتاب قيم و تسلسل الافكار رايع
# كتاب قيم و تسلسل الافكار رايع
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# الرب فوق كل تصور، فوق كل انسان، فوق كل كمال
# الرب فوق كل تصور، فوق كل انسان، فوق كل كمال
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1- حنفين المذهب ولديهم ميول صوفيه فالاولي
# 1- حنفين المذهب ولديهم ميول صوقيه فالاولي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# اعجبني ف الكتاب انه بشكل او باخر لمس حاجات كتنير جوانا وعبر عنها ومن اكتر الجمل التي استوقفتني :
# اعجبني ف الكتاب انه بسكل او باخر لمس حاجات كتنير جوانا وعبر عنهأ ومن اكتر الجنل اكتي استوقفتني :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# و هون الخطوره
# و هون الخطوره
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# الثلاث نجوم عشان اخر فصل وما يحتويه من كلام رايع
# الثلاث نجوم عشان اخر فصل وما يحتويه من كلام رايع
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# انصح بقرايتها للفايده اولا و المتعه و الدهشه ??
# انصح بقرايتها للفايده اولإ و النتعه و الدهشه ??
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# هل كان يتنبا بان كل هذا الكبت وكل هذا الاغتراب في حياه الشعب التونسي ستنتهي بثوره
# هل كان يتنبا بان كل هذا الكبت وكل هذا الاغتراب في حياه الشعب التونسي ستنتهي بثوره
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# المشكله ليست في التمسك بالسنه ولكن القضيه في الطرح الذي يحمله هولاء
# المشكله ليست قي التمسك بالسنه ولكن القضيه في الطرح الري يحمله هولاء
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# جزي المولف عنا خير الجزاء
# جزي المولف عنا خير الجزاء
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# لا اتفق معها ف ذلك ،، بالطبع نحتاج الي حكمه الكبار كثيرا ،، لكن وجود الشباب امر ضروري واساسي
# لا انفق معها ف ذلك ،، بالطبع بحتاج الي حكمه الكبار كثيرا ،، لكن وجود الشباب امر ضروري واساسي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ليه دايما فيه روايات بتحاول تزينلك الغلط
# ليه دايما فيه روايات بتحاول تزينلك الغلط
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# بالمعني الحرفي
# بالمعني الحرفي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# من افضل واروع الروايات التي قراتها في حياتي علي الاطلاق
# من ىفضل واروع الروايات التي قراتهى في حياني غلي الاطلاق
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# وقد ذكرتني هذه الروايه ب (The hateful eight) لمن يعرفها
# وقد ذكرتني هذه الروايه ب (The hateful eight) لمن يعرفها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# بس في المجمل مشدتنيش خالص وحسيتها ممله :(
# بس في المجمل مشدتنيش جالص وحسيتها ممله :(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# استشفيت هنا رجل عربي لديه غيره علي نساءه
# استشفيت هنا رجل عربي لديه غيره علي نساءه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لكنني وقعت في غرام الجد "محتشمي زايد" و اعتقد ان جميعكم سيفعل لانه الشخصيه الممتعه جدا
# ككنني وقعت في غرام الجد "محتشمي زايد" و اعتقد ان جميعكم سيفعل لانه الشخصيه الممتعه جدا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# عشنا سنوات نتغتني بضياع الجنه بضياع الاندلس لكن بدون ان نشعر او نفهم لما ضاعت او كيف كانت
# عشنى سنوات نتغتني بضياع الجنه بضياع الاندلس لكن بدون ان نشعر او نفهم لما ضاعت ءو كيف كانت
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ولهذا لهم قبول كبير جدا بين الشباب وبالفعل حققوا نجاحات عجز اساتذتهم عن بلوغ معشارها
# ولهذا لهم قبول كبير جدا بين الشباب وبالفعل حققوا نجاحات عجز اساتذتهم عن بلوغ معشارها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ابتهل الي الله ان يخلص جمانه من براثن حب ولد معاقا مريضا ميتا
# ابتهل الي الله ان يخلص جمانه من بزاثن حب ولد معاقا مريضء ميتا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ذات الهمجيه والعنجهيه البشريه التي قد نجدها ذاتها في انسان متحضر ننقله نحو غابه
# ذات الهمجيه والعنجهيه البشريه التي قد مجدها ذاتها فى انسان متحضر ننقله نخو غابه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# ايضا لا تستطيع التغاضي عن ماهيه العلاقه التي نشات بين هازيل والممرضه
# ايضا لا تستطيع التغاضي عن ماهيه العلاقه التي نشات بين هازيل والممرضه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# وهولاء كلهم
# وهولاء كلهم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# "-ماذا ينقص الانسان ليحظي بنعمه الزمان و المكان
# "-ماذا ينقص الانسان ليحظي بنعنه الزمان و المكان
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ان يصبح المرء منا بلا ماض يستند اليه ليمضي قدما الي المجهول
# ان يصبح المرء منا بلا ماض يستند اليه ليمضي قدما ءلي المجهول
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# فيه صدق ووضوح ولغته البسيطه تجعلك تقراه بسهوله ومتعه
# فيه صدق ووضوح ولغته البسيطه تجعلك تقراه بسهوله ومتعه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# يحكي الكتاب عن اسطوره رجال الاعمال الوطنيين المخلصين في مصر
# يحكب الكتاب عن اسطوره رجال الاعمال الوطنيين المخلصين في مصر
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# " اعرف انها جراه ان يكتب تراب خاطيء مثلي عن الله
# " اعرف انها جراه ان يكتب تراب خاطيء مثلي عن الله
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# الروايه جميله، بحس موراكامي عاوز يوصل القاريء لحاله معينه من غير
# الروايه جميله، بحس موراكامي عاوز يوصل القاريء لحاله معينه من غير
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# تحاول سيمون في هذا الكتاب الاجابه علي السوال التالي :
# تحاول سيمون في هذإ اككتاب الاجابه علي السوال التالي :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# هتعرف الرقي في الفكر والثقافه , وهتعرف ازاي كان بيتعامل شريحه واسعه من المثقفين
# هتعرف الرقي في الفكر والثقافه , وهتعرف ازاي كان بيتعامل شريحه واسعه من المثقفين
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# السوال اللي كان شاغلني اثناء القراءه :
# السوال اللي كان شاغلني اثناء القراءه :
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# وحين ادركت ان هذه الاغنيه تصلح موسيقي تصويريه لحوار ساييري لذاته، ابتسمت وعفوت عن الشخص المزعج
# وحين ادركت ان هذه الاعنيه تصلح موسيقي تصويريه لحوار ساييري لذاته، ابتسمت وعفوت عن الشخص المزعج
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# من افضل ما قراته في ادب الرعب ^_^
# من افضل ما قرءته في ادب الرعب ^_^
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# شعرت لوهله ان الروايه ناقصه
# شعرت لوهله ان الروايه ناقصه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# المجموعه من الحجم القصير، تقريبا خمس قصص، لو رتبناهم من حيث المتعه
# المجموعه من الحجم القصير، تقريبا خمس قصص، لو رتبناهم نن حيث المتعه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# رغم ان مش كل القصايد عجبتني لكن في قصايد استمتعت بيها جدا
# رغم ان مش كل القصايد عجبتني لكن فب قصايد استمتعت بيها جدا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ممله جدا جدا لم استطع ان اكملها علي العكس تماما من 2 ظباط
# ممله جدا جدا لم استطع ءن اكملها علي العكس تماما من 2 ظباط
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# اسلوب ضعيف جدا , استخدام مبالغ لفطره الجنس و دا بيعدك عن الاحدااث و مضمون القصه من دون مبرر
# اسلوب ضغيف جذا , استخدام مبالغ لفطره الجمس و دا بيعدك عن الاحدااث و مضمون القشه من دون مبرر
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ركز بالاساس علي النظره الذكوريه للانثي التي لا تتعدي الجسد والعمليه الجنسيه
# ركز بالاساس عكي النظره الذكوريه للانثي التي لا تتعدي الجسد والعمليه الجنسيه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# خلتني اعيد حسابات كتير
# خلتني اعيد حسابات كتير
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# الروايه دي اقل ما يمكن ان يقال عليهارايعه
# الروايه دي اقل ما يمكن ان يقال عليهارايعه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# يعني مش هيبقي حد صادق و مخلص و الله يعلم منه ذلك ثم يضله
# يعني مش هيبقي حد صادق و مخلص و الله يعلم منه ذلك ثم يضله
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 4-حريه الجنس
# 4-حريه الجنس
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# والروايه او اي شي مكتوب مش كثير حلو وغير متناسق :((
# والروايه او اي شي مكتوب مش كثير حلو وعير متناسق :((
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# و في نظر اخونا شاكر فمستحيل ان الواحد يتجرد من افكاره السابقه و بالتالي المنهج ده غلط
# و في نظر اخونا شاكر فمستحيل ان الواحد يتجرد من افكاره السابقه و باكتالي المنهج ده غلط
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# اعلم اني دراميه في قرايتي لهذا الكتاب بالذات
# اعلم اني دراميه في قرايتي لهذا اللتاب بالذات
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# شيء شارد، تحس به الحواس كلها، ولكنه يراوغها جميعا
# شيء صارد، تحس به الحواس كلهإ، ولكنه يراوغها جميعا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# الي حين
# الي حين
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# فمن يكتب لا يموت ابدا
# فمن يكتب لا يموت ابدا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# لم يعد احد من الموتي ليخبرنا الحقيقه
# لم يعد احد من الموتي ليخبذنا الحقيقه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# وعند هروبه من القصر
# وغند هروبه من القصر
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ونهايته رايعه واحداثها متسارعه
# ونهاىته رايعه واحداثها متسارعه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# معضله الموت في سبيل الحياه
# معضله الموت في سبيل الحيىه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# من الناحيه الادبيه ليس هناك ما يجذب ويشوق للاستزاده
# من الناحيه الادبيه ليس هناك ما يجذب ويشوق للاستزاده
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# تمنيت لو ان كان ابن الصحراء التي ينتسب اليها
# تمنيت لو ان كان ابن الصحراء التي ينتسب اليها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# =- حينما يكون للحزن معني اخر مختلف عن مجرد انه يولم قلبك ويدميه
# =- حينما يكون للحزن معني اخر مختلف عن مجرد انه يولم قلبك ويدميه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# افيد من حصص التاريخ
# افيد من حصص التاريخ
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# راقت لي الاغاني الشعبيه التي كررت في الروايه
# راقت لي الاغاني الشعبيه التي كررت في الروايه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# تستحق اكثر من ? نجوم ولا استغرب كل الضجه التي اثيرت حول هذا الكتاب فقد كانت مستحقه
# تستحق اكثر من ? نجوم ولا استغرب كل الضحه التي اثيرت حول هذا الكتاب فقد كانت مستحقه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# الفكره او الموضوع: مميزه للغايه , تجمع بين الرعب والتشويق , الدمويه , الانسانيه
# الفكره او الموضوع: مميزه للغايه , تجمع بين الرغب والتشويق , الدمويه , الانسانيه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# الديوان لمسني بصوره شخصيه
# الديوان لمسمي بصوره شخصبه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ونفسي اعرف فايده الدكتور اللي محاضرته عباره عن قرايه لروايه
# ونفسي اعرف فايده الدكتور اللي محاضرته عباره عن قرايه لروايه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# من المفترض ان تكون الروايه من ضمن الادب الانجليزي لروعتها
# من المفترض ان تكون الروايه من ضمن الادب الانجليزي لروعتها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# بطل القصه تجسيد لكل شاب مسلم متحمس وفي القصه مراحل ومحطات يمر بها الشباب الاسلامي كثيرا
# بطل القصه تجسيد لكل شاب مسلم متحمس وقي القصه مراحل ومحطات يمر بها الشباب الاسلامي كثيرا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ، من امتع ما قرات علي الاطلاق لمراسل الابندبندنت في الشرق الاوسط
# ، من امتع ما قرات علي الاطلاق لمراسل الابندبندنت في الشرق اكاوسط
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# علاقاتها واسعه في الاوساط الادبيه
# علاقاتها واسعه في الاوساط الادبيه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لكن انا حاسه ان فالرق مش جامد
# لكن انا حاسه ان فالرق نش جاند
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# دي اول روايه طويله للكاتب
# دي اول روايه طويله للكاتب
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لكن كل ما دار كحوار بداخل الروايه طلام الخطوبه مع خطيبها في الهاتف فهذا لا يجوز الا من خلال والدها
# لكن كل ما دار كحوار بداخل الروايه طلام الخطوبه مع خطيبها في الهاتف فةذا لا يجوز الا من خلال والدها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# مغامره في الادغال استمتعت جدا بقرايتها
# مغامره في الادغال استمتعت جدا بقرايتها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ابدا لم يبخل علي الله برسالاته
# ابدا لم ىبخل علي الله برسالاته
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لم يكن الكلام سلواي في يوم من الايام ، وقد عرفت
# لم يكن الكلام سلواي فب يوم من الايام ، وقد عرفت
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# مجموعه مقالات تحاكي الواقع
# مجموعه مقالات تحالي الواقع
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# هتقرا عن الشخصيه من وجهه نظر صاحبها ومن وجهه نظر 3 اخرين
# هتقرا عن الشخصيه من وجهه نظر صاحبها ومن وجهه نظر 3 اخرين
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# #للكاتبه_دينا_علي
# #للكاتبه_دينا_علي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# وهي تعتمد علي فكره
# وهي تعتمد علي فكره
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# تبا لي ،يا لي من رجل يفكر بعضوه الذكري
# تبا لي ،يا لي من رجل بفكر بعضوه الذكري
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# رسايل بسيطه تناقش ظواهر اجتماعيه واخلاقيه ظهرت في مجتمعنا الاسلامي
# رسايل بسيطه تناقش ظوىهر اجتماعيه واخلاقيه ظهرت في مجتمعنا الاسلامي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# اعجبني الكتاب، وجدت به شييا مما كنت ابحث عنه، و لو انه مجرد لمحه
# اعجبني الكتاب، وجدت به شييا مما كنت ابحث عنه، و لو امه مجرد لمجه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# بالرغم من الكتاب يحتوي علي بعض التفاول و بعض النصايح المفيده
# بالرغم مب الكتاب يحتوي علي بعض التفاول و بعض النصايح المفيده
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# الوطن هم اوليك اللذين لم يكتفوا بذرف الدموع
# الوطن هم اوليك اللذين لم يكتفوا بذرف الدموع
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ليتها انتهت بمنطقيه كما ابدت بشبه منطقيه
# ليتها انتهت بمنطقيه كما ابدت بشبه منطقيه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# الي علي الذي قضي عمره كله بين الغربه و الترحال و لم يتركه الخوف و لا الوحده لحظه في حياته
# الي علي الذي قضي عمره كله بين الغربه و الترحال و لم يتركه الخوف و لا الوحده لحظه في حياته
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# نجمتان فقط هو تقديري لهذه الروايه الغريبه
# نجمتان فقط هو تقديري لهذه ألروايه الغريبه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 468 صفحه لييييييه
# 468 صفحه لييييييه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# شهاده حق تعطي قيمه للكتاب
# شهاده حق تعطي قيمه للكتاب
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# يمكن انا كنت عديت موضوع العاطفه الزايده ده في مالك
# ينكن انا كنت عديت موضوع العاظفه الزايذه ده في مالك
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# وتخترعين بلادا اليها ذهبنا
# وتخنرعين بلادا اليها ذهبنا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# هل هو عادل حقا
# هل هو عادل حقا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# لكنه بيد الافهام منهوب
# لكنه بيد الافهام منهوب
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لا يمكر الله الا مع من يبدا بالمكر
# لا يمكر إلله الا مع من يتدا بالمكر
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# بالرغم من شناعه تصميمه واخراجه وكثره الالوان والصور
# بالرغم من شناعه تصميمه واخراجه وكثره الالوان والصور
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# عندما يتجسد الاحساس في روايه
# عندما يتجسد الاحساس في رواىه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# الجزء الخاص بسوسن
# الجزء الجاص بسوسب
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# من تناقضات رام الله
# من تناقضءت زام ألله
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# تصورها افضل لان الخيال في الدراما المصريه مش قوي
# تصورها افضل لان الخيال في الدراما المصريه مش قوي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# فعلا علي الوردي قد سبق عصره بمراحل طوييله جدا
# فعلا علب الوردي قد سبق عصره بمراحل طوييله جدا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ولكن احيانا قليله كانت تخرج عن هذه القاعده لتبهرني بكلماتها
# ولكن احيانا فليله كانت تخرج عن هره القاعده لتبهرني بكلماتها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# , الا انهم ما ان يدخلوا القصر حتي يتمنوا ان يخرجوا منه ,
# , الا انةم ما ان يدخلوا القصر حتي يتمنوا ان يخرجوا منة ,
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# تفاصيل الحزن والخيبه و الالم وهذا الجسر، سبب كل الالم
# تفاصيل الحزن والخيبه و الالم وهرا الجسر، سبب كل الىلم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# اعجبتني الروايه من حيث عرض الكاتبه للمبررات التي يضعها كل امام معتقداته ليجعلها صحيحيه من وجهه نظره
# اعجبتني الروايه من حيث عرض الكاتبه للمبررات ألتي يضعها كل امام معتقداته ليجعلها صحيحيه من وجهه نظره
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# كلها عقد العصر الحديث و رواسب الحداثه لذلك انطلق هاروكي في رحله بين جدران العالم الحديث
# كلها عقد العصر الحديث و رواسب الحداثه لذلك انطلق هاروكي في رحله ببن جدران العالم الحديث
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# واقام علي سفر ,, وفارق علي عجل
# واقإم علي سفر ,, وفارق علي عجل
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# روايه واقعيه جميله مفيهاش الاحداث ال
# روايه واقعيه جميله مفيهاش الاحداث اك
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ياكل عرقهم اكابر قريتهم و مترفي الوسيه بالاتفاق
# ياكل عرقهم اكابر قريتهم و مترفي الوسيه بالاتفاق
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ممتليه بالشحن
# ممتليه بالشحن
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# لتاخذ طريقا محايدا
# لتاخذ طريقا محايدا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# دمتي مبدعه استاذه دعاء
# دمتي مبدعه استاذه دعاء
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# خلسه، وبمداراه ارمي ما اخبيه من قصاصات، مثل الاطفال، دون ان اجرو علي التصايح مثلهم
# خلسه، وبمذاراه ارمي ما اخبيه من قصاصات، مثل الاطفال، دون اب احرو علي التصايح مثلهم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# فصار الهنود الحمر تراث همجي امتلك اكثر مما يكفيه او مما يستحق
# فصار الهنود الحمر تراث همجي امتلك اكثر مما يكفيه او مما يستحق
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# لا تغتر يا ابني بهذه الالوان
# لا تعتر يا ابني بهذه الالوان
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# هذه هي مصر التي نعيشها
# هذه ةي مصر التي نعيشها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# الخيانه كالهواء , تدلف الي منازلنا بمجرد فتح الباب
# الخىانه كالهواء , تدلف الي منازلنا بمجرد فتح الباب
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# فقط لولا التفصيلات الممله احيانا و بعض المبتذلات
# فقط لولا التفصيلات الممله احيانا و بعض المبتذلات
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لا اجد في هذه الروايه سوي اناقه الحرف وبلاغه الكاتبه
# لا اجد في هذه الروايه سوي اناقه الحرف وبلاغه الكاتبه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# الروايه جيده جدا وانا حبيتها تقيمي ليها 3 نجوم ونص واظن اني هعيد قرايتها مره اخري بعد فتره من الوقت
# الروايه جيده جدا وانا حبيتها تقيمى ليها 3 نجوم ونص واظن اني هعبد قرايتها مره اخرى بعد فنره من الوقت
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# اكملتها مرغمه لاني لا اترك كتابا بدات به
# اكملتها مرغمه لاني كا اتذك كتاتا بدات به
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# هل يوجد هدف لنعمل من اجله لكي نجد خلاصا لانفسنا
# هل يوجد هدف لنعمل مب اجله لكي نجد خلاصا لانفسنا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# لمسه الرومانسيه الهاديه و قصه حبهم البسيطه كان ليها وقع السحر عليا في وسط روايه بالشكل ده
# لمسه الرومانسيه الهاديه و قصه حبهم البسيطه كان ليها وقع السخر عليا في وسط روايه بالشكل ده
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# وكذلك يصلح لغسل المزاج من اثار سهره مزعجه لم تكن علي البال
# وكذلك يصلح لغسل المزاج من اثار سهره مزعجه لم تكن علي البال
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# في هذا الكتاب تجد غازي الشيخ
# في هذا الكتاب تجد غازي الشيخ
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# مزرعه البنات
# مزرعه البنات
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# يجعلنا اقدر علي موجهتها و الوعي بابعادها
# يجعلنا اقذر علي موجهتها و الوعي بابعادها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ومازال الطبيب يجاهد ليظل حيا
# ومازال الطبيب يجاهد ليظل حيا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# سعيد فريحه: " سياده الرييس مالنا وما لك
# سعيذ فريحه: " سياذه الرييس مالنا وما لك
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# وتبكين حبا
# وتبكين جبا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# السعيد هو السعيد ليلا والشقي هو الشقي ليلا اما النهار ف يشغل اهله :))
# السعيد هو السعيد ليلا والشقي هو الشقي ليلا أما النهار ف يشغل اهله :))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# جميله اللغه في هذا الكتاب
# جميله اللغه في هذا الكتاب
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# فلقد زرع امام منزله شجيرات من تين وبرتقال ، يعلم جيدا ان لن يري ثمرها في البعاد
# قلقد ززع امام منزله شجيرات من تين وبرتقال ، يعلم جيدا ان لن يري ثمرها في البعاد
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# بالسنه تهمهم بالدعاء و اجفان تفيض من الدموع ،
# بالسنه تهمهم بالدعاء و اجفان تفيض من الدموع ،
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# خيل المغيرين من احفاد (معتصم)
# خيل المغيرين مم احفاد (معتصم)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# اللهم ارحم شيخنا محمد الغزالي
# اللهم ارحم شيخنا محمد الغزالي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# من خلال الروايه لمحت في الكاتب ذكاءه حيث اقتبس لخوسيه ريزال
# من خكال الرواية لمحت في الكاتب ذكاءه حيث اقتبس لخوسيه ريزال
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# نعم،لكن هنا يتجلا ماركيز ملك السرد ويمسك بنا حتي نهايه الروايه بشغف
# نعم،لكن هنا يتجلا ماركيز ملك السرد وىمسك بنا حتي نهايه الروايه بشغف
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ورحت ابتعد عن تعاليم الاسلام وانا اتصور انني ازداد تعمقا فيها
# ورحت ابتعد عن تعاليم ءلاسلام وانا اتصور انني ازداد تعمقا فيها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# نهار او ليل، باي حال، مكتبتي هي عالم خاص
# نهار او ليل، باي حال، مكتبتي هي غالم خاص
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# يتحدث الرافعي في اغلب مقالاته عن الادب والاديب والفضيله والوضاعه
# يتحدث الرافعي في اغلب مقالاته غن الاذب والاديب والفضيله والوضاعه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# - يوحنا المجنون
# - يوحنا المجنون
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# (او هكذا هو المفترض منها)
# (او هكذا هو المفترض منها)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# ورغم ذلك فشلت في ان تخرج كتاب قايم علي اساسه
# ورغم ذلك فشلت في ان تخرج كتاب قايم علي اساسه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# في الغالب هرجع اقراه تاني كتييير :)
# في الغالب هرخع اقراه تاني كتييير :)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# تجربه غيرت كل من خاضها الي الابد
# تجربه غيرت لل من خاضها الي الابد
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# غريبه انت
# غريبه انت
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# السذاجه، والطيبه، واتساع الصدر
# السذاجه، والطيبه، واتساع الصدز
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# و سنتعلم في الحالتين
# و سنتعلم في الحالتين
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# طبعا تاثير دكتور هووس علي الكاتب واضح جدا في الشخصيات
# طبعا تإثير دكتور هووس علي الكاتب واضح جدا في الشخصيات
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# رااااايعه تلك الكلمات
# رااااىيعه تلك الكلمات
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# استطاع الدكتور ايمن ايصال رساله الدكتور اياد اسعد للقاري
# استطاع الدكتور اىمن إيصال رساله الدكتور اياد اسعد للقاري
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# ونحن مجرد مستاجرين يتم طردنا من الحياه فيها في اي وقت
# ونحن مجرد مستاجرين يتم طردنا مب الحياه فيها في اي وقت
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# و التالته عشان علمتني مقراش لمحمد المنسي تاني
# و التالته عشان علمتني مقراش لمحمد المنسي تاني
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ويدخل في مملكه الماء
# ويدخل في مملكه اكماء
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# بالشخصيات و اختلافها
# بالشخصيات و اخنلافها
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# لا باس ان تري سجينا كل ما تببقي فيه هو هيكله العظمي
# لا باس ان تري سجينا كل ما تببقي قيه هو هيكله العظمي
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# كانت الفكره تلك (عرض الانفعالات والمشاعر الناتجه عن الحدث قبل ذكر الحدث نفسه) موفقه
# كانن الفكره تلك (عرض الانفعالات والمشاعر الناتجه عن الحدث قبل ذكر الحدث نفسه) موفقه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ناسيا انهم مجرد بشر، بامكان الزمن ان يمضي بهم في
# ناسيا إنهم مجرد بشر، بامكان الزمن ان يمضي بهم في
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# مافيش وسيطه في الشخصيات طيب اووي شرير جداا
# مافيش وسيطه في الشخصيات طيب اووي شرير جدىا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# سنوات مها بوسا مع سالم
# سنوات مها بوسا مع سالم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# طاقه متحركه
# طاقه متحركه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# كتاب اعمق كثيرا من ان يوصف بالروايه لانه حقيقه نظره فلسفيه بسرد متقن لكوامن بشريه
# كتاب اعمق كثيرا من ان يوصف بالروايه لانه حقيقه نظره فلسفيه بسرد متقن لكوامن بشريه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# لا كما يجب ان تبذر علي غموض حب يصل نحو الهاويه
# لا كمى يجب ان تبذر علي غموض حب يصل نحو الهاويه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# وعدل الله لا بتخلف، فلا تلوموا النصيب والقدر والمكتوب والحظ، وانما لوموا انفسكم
# وعدل الله لا بتخلف، فلا تلوموا النصيب والقدر والمكتوب والحظ، وانما لوموا انفسكم
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ايه مصير سلوي وعصام وليه سلوي كانت ملحده المعلومه دي لم توثر علي الروايه
# ايه مصير سلوي وعصام ولىه سلوي كانت مكحده النعلومه دي لم توسر علي الروايه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# يحدث كثيرا
# يحدث كثيرا
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# "انما قيمه الاشياء بما فيها من اثر القلب او بما لها في القلب من اثر "
# "انما قيمه الاشياء بما فيها من اثر القلب او بما لها في القلب من اثر "
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# انا بجد المتعه في قراءه لاحمد خالد توفيق
# انا بحد المتعه في قراءه لاحمد خالد توفيق
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# , It equals GENIUS for me ^_^ :D
# , It equals GENIUS for me ^_^ :D
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# موجعه هي اوجاع الفلسطينيين
# موجعه هي اوجاع الفلسطينيين
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# فتره غيرت مجري الاحداث بشكل جزري و قلبت الموازين من حال لحال
# فتره غيرت مجري الاحداث بشكل جزري و قلبت الموازين من حال لحاك
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# مش انت الي بتقول
# نش انت الي بتقول
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# اسلوب في الكتابه اكتر من رايع يبحر بك في عالم القصه ويجعلك احد الشخصيات
# اسلوب في الكتابه اكتر نن رايع ينحر بك في عالم القصه ويجعلك احذ الشخصيات
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# الكتاب عباره عن مجموعه خواطر
# الكتاب عباره عن مجموعه خواطر
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# في كل مره اجد اني امسكت زمام الامور اجد اني اضعتها ثانيه
# في كل نره اجد اني امسكت زمام الامور اجد اني اضعتها ثانيه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# لتعبر عما يود قلمي البوح به
# لتعبر عما يود قلمي البوح به
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# كتاب جيد لتغريدات د/سلمان العوده
# كتات جيد لتغريدات د/سلمان العوده
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# يستحق النجمه الواحده لولا بعض الخواطر الجيده والموثره كقصص زواج اخواته
# يستحق النجمه الواحده لولا بعض الخواطر الجيده والموثره كقصص زواج اخواته
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# مفيش نهايات سعيده كده خالص
# مفيش نهايات سعيده كده خالص
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# حرمت وحللت ووضعت القوانين لتناسب نشاته رغم انف من اعجبه ولم يعجبه
# حرمت وحللت ووضعت القوانين لتناسب نشاته رغم انف مم اعجبه ولم يعجنه
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# بداته، وفجاه وجدت نفسك قد التهمته كله
# بداته، وفجاه وجدت نفسك قذ التهمته كله
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ياعم سيبني اتفاجيء ساعتها وخلاص مش علي طول لاحقني (الهم جاي الهم جاي ) :D
# ياعم سيبني اتفاجيء ساعتها وحلاص مش علي طول لاحقني (الهم جاي الهم جاي ) :D
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# عقلي استفرغ كل شيء
# عقكي اسنفرغ كل شيء
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# والهدف من الكتاب كما فهمته
# والهدف من الكتاب كما فهمته
# Sentence-level accuracy: 0.7900

# %%
def evaluate_autocorrect_model(clean_sentences, noisy_sentences, verbose=True):
    assert len(clean_sentences) == len(noisy_sentences), "Mismatched input lengths."
    
    sentence_correct = 0
    word_accuracies = []
    
    for clean, noisy in zip(clean_sentences, noisy_sentences):
        predicted = autocorrect(noisy)
        
        if predicted == clean:
            sentence_correct += 1
        
        # Word-level accuracy
        clean_words = clean.split()
        predicted_words = predicted.split()
        correct_words = sum(1 for cw, pw in zip(clean_words, predicted_words) if cw == pw)
        word_accuracy = correct_words / max(len(clean_words), 1)
        word_accuracies.append(word_accuracy)

        # if verbose and predicted != clean:
        print("🔸 Noisy:     ", noisy)
        print("🔁 Predicted:", predicted)
        print("✅ Target:   ", clean)
        if predicted == clean and noisy != clean: 
            print("Corrected a mistake!")
        if predicted == clean and noisy == clean: 
            print("Correct, but no mistake was found")
        print()

    total = len(clean_sentences)
    print(f"\n📏 Sentence-level accuracy: {sentence_correct}/{total} = {sentence_correct/total:.2%}")
    print(f"📊 Avg. word-level accuracy: {np.mean(word_accuracies):.2%}")

# %%
sentence1 = "أنا أجب المدرصة"
sentence2 = "أنا أشعر بالحوع"
sentence3 = "الحديقة حميلة جدًا"
sentence4 = "أدرس اللغة العزبية"
sentence5 = "أحب أتغلم البرمجة"
sentence6 = "السماء ززقاء صافية"
sentence7 = "مغالجة اللغات الطبيعية"
print(autocorrect(sentence7))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# معالجه اللغات الطبيعيه

# %%
import tkinter as tk
# handles button press
def correct_sentence():
    input_text = entry.get()
    corrected = autocorrect(input_text)
    result_label.config(text="🔧 التصحيح: " + corrected)

root = tk.Tk()
root.title("Arabic Sentence Autocorrector")
root.geometry("500x200")

# Label
label = tk.Label(root, text="أدخل الجملة العربية:", font=("Arial", 14))
label.pack(pady=10)

# Text entry
entry = tk.Entry(root, font=("Arial", 14), justify='right')
entry.pack(fill='x', padx=20)

# Button
button = tk.Button(root, text="تصحيح", font=("Arial", 12), command=correct_sentence)
button.pack(pady=10)

# Output label
result_label = tk.Label(root, text="", font=("Arial", 14), fg="green", wraplength=480, justify='right')
result_label.pack(pady=10)

# Run GUI loop
root.mainloop()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
